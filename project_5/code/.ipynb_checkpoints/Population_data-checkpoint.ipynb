# %% [markdown]
# # Population of the US counties

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# set path to data folder in case we move this all around
path_to_home = '../'
path_to_data = 'data/BIG-QUERY/'
filename = 'clean_county_population.csv'

cnty_pops = pd.read_csv(path_to_home+path_to_data+filename)

# %%
cnty_pops.head()
# Out:
#             Geographic Area     Census  Estimates Base       2010       2011  \
# 0  United States of America  308745538       308758105  309321666  311556874
# 1  .Autauga County, Alabama      54571           54597      54773      55227
# 2  .Baldwin County, Alabama     182265          182265     183112     186558
# 3  .Barbour County, Alabama      27457           27455      27327      27341
# 4     .Bibb County, Alabama      22915           22915      22870      22745
#
#         2012       2013       2014       2015       2016       2017  \
# 0  313830990  315993715  318301008  320635163  322941311  324985539
# 1      54954      54727      54893      54864      55243      55390
# 2     190145     194885     199183     202939     207601     212521
# 3      27169      26937      26755      26283      25806      25157
# 4      22667      22521      22553      22566      22586      22550
#
#         2018       2019
# 0  326687501  328239523
# 1      55533      55869
# 2     217855     223234
# 3      24872      24686
# 4      22367      22394
